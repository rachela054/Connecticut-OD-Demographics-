# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pp
from datetime import datetime
import seaborn as sns 
import matplotlib as mpl

# %%
#import dataset with CT opoiod overdoes deaths
death = pd.read_csv('Accidental_Drug_Related_Deaths__2012-June_2017.csv')

# %%
death.head(10)
# Out:
#   CaseNumber        Date  Day  Month  Year     Sex             Race   Age  \
# 0     15-777         NaN    0      1  1900    Male            White  28.0
# 1   15-16348         NaN    0      1  1900     NaN              NaN   NaN
# 2   12-18447  12/29/2012   29     12  2012    Male            White  30.0
# 3   12-14640  10/18/2012   18     10  2012    Male            White  19.0
# 4      21885   5/30/2012   30      5  2012    Male            White  35.0
# 5      20424   6/21/2012   21      6  2012    Male            White  29.0
# 6      23346   5/24/2012   24      5  2012    Male            Black  53.0
# 7   12-12055   8/27/2012   27      8  2012    Male  Hispanic, White  71.0
# 8   12-11530   8/15/2012   15      8  2012    Male  Hispanic, White  44.0
# 9   12-13673   9/30/2012   30      9  2012  Female  Hispanic, White  32.0
#
#   ResidenceCity ResidenceState                   ...                     \
# 0           NaN            NaN                   ...
# 1           NaN            NaN                   ...
# 2       WOLCOTT            NaN                   ...
# 3       SUDBURY            NaN                   ...
# 4    BRIDGEPORT            NaN                   ...
# 5    ROCKY HILL            NaN                   ...
# 6    NEW LONDON            NaN                   ...
# 7     NEW HAVEN            NaN                   ...
# 8     NEW HAVEN            NaN                   ...
# 9    MIDDLETOWN            NaN                   ...
#
#   Benzodiazepine Methadone Amphet Tramad Morphine (not heroin)    Other  \
# 0            NaN       NaN    NaN    NaN                   NaN      2-A
# 1            NaN       NaN    NaN    NaN                   NaN      NaN
# 2            NaN       NaN    NaN    NaN                   NaN      NaN
# 3              Y       NaN    NaN    NaN                   NaN      NaN
# 4            NaN       NaN    NaN    NaN                   NaN      NaN
# 5            NaN       NaN    NaN    NaN                   NaN      NaN
# 6            NaN       NaN    NaN    NaN                   NaN      NaN
# 7            NaN       NaN    NaN    NaN                   NaN  OPIATES
# 8            NaN       NaN    NaN    NaN                   NaN      NaN
# 9            NaN       NaN    NaN    NaN                   NaN      NaN
#
#   Any Opioid MannerofDeath AmendedMannerofDeath  \
# 0        NaN           NaN                  NaN
# 1        NaN      Accident                  NaN
# 2        NaN      Accident                  NaN
# 3        NaN      Accident                  NaN
# 4        NaN      Accident                  NaN
# 5        NaN      Accident                  NaN
# 6        NaN      Accident                  NaN
# 7        NaN      Accident                  NaN
# 8        NaN      Accident                  NaN
# 9        NaN      Accident                  NaN
#
#                                   DeathLoc
# 0              CT\n(41.544654, -72.651713)
# 1              CT\n(41.544654, -72.651713)
# 2   WATERBURY, CT\n(41.554261, -73.043069)
# 3  BRIDGEPORT, CT\n(41.179195, -73.189476)
# 4  BRIDGEPORT, CT\n(41.179195, -73.189476)
# 5    HARTFORD, CT\n(41.765775, -72.673356)
# 6  NEW LONDON, CT\n(41.355167, -72.099561)
# 7   NEW HAVEN, CT\n(41.308252, -72.924161)
# 8   NEW HAVEN, CT\n(41.308252, -72.924161)
# 9  MIDDLETOWN, CT\n(41.544654, -72.651713)
#
# [10 rows x 35 columns]

# %%
death.describe()
list(death)
# Out:
# ['CaseNumber',
#  'Date',
#  'Day',
#  'Month',
#  'Year',
#  'Sex',
#  'Race',
#  'Age',
#  'ResidenceCity',
#  'ResidenceState',
#  'ResidenceCounty',
#  'DeathCity',
#  'DeathState',
#  'DeathCounty',
#  'Location',
#  'DescriptionofInjury',
#  'InjuryPlace',
#  'ImmediateCauseA',
#  'Heroin',
#  'Cocaine',
#  'Fentanyl',
#  'Oxycodone',
#  'Oxymorphone',
#  'EtOH',
#  'Hydrocodone',
#  'Benzodiazepine',
#  'Methadone',
#  'Amphet',
#  'Tramad',
#  'Morphine (not heroin)',
#  'Other',
#  'Any Opioid',
#  'MannerofDeath',
#  'AmendedMannerofDeath',
#  'DeathLoc']

# %%
#deleate unwanted columns and set index 
death_index = death.drop(['ResidenceState','DeathState','DescriptionofInjury','ImmediateCauseA','MannerofDeath','DeathLoc', 'DescriptionofInjury', 'AmendedMannerofDeath'], axis= 1)

# %%
death_index = death_index.set_index(['Date'])
death_index.head()
# Out:
#            CaseNumber  Day  Month  Year   Sex   Race   Age ResidenceCity  \
# Date
# NaN            15-777    0      1  1900  Male  White  28.0           NaN
# NaN          15-16348    0      1  1900   NaN    NaN   NaN           NaN
# 12/29/2012   12-18447   29     12  2012  Male  White  30.0       WOLCOTT
# 10/18/2012   12-14640   18     10  2012  Male  White  19.0       SUDBURY
# 5/30/2012       21885   30      5  2012  Male  White  35.0    BRIDGEPORT
#
#            ResidenceCounty   DeathCity    ...     Oxymorphone EtOH  \
# Date                                      ...
# NaN                    NaN         NaN    ...             NaN  NaN
# NaN                    NaN         NaN    ...             NaN  NaN
# 12/29/2012       NEW HAVEN   WATERBURY    ...             NaN  NaN
# 10/18/2012       MIDDLESEX  BRIDGEPORT    ...             NaN  NaN
# 5/30/2012        FAIRFIELD  BRIDGEPORT    ...             NaN  NaN
#
#            Hydrocodone Benzodiazepine Methadone Amphet Tramad  \
# Date
# NaN                NaN            NaN       NaN    NaN    NaN
# NaN                NaN            NaN       NaN    NaN    NaN
# 12/29/2012         NaN            NaN       NaN    NaN    NaN
# 10/18/2012         NaN              Y       NaN    NaN    NaN
# 5/30/2012          NaN            NaN       NaN    NaN    NaN
#
#            Morphine (not heroin) Other Any Opioid
# Date
# NaN                          NaN   2-A        NaN
# NaN                          NaN   NaN        NaN
# 12/29/2012                   NaN   NaN        NaN
# 10/18/2012                   NaN   NaN        NaN
# 5/30/2012                    NaN   NaN        NaN
#
# [5 rows x 27 columns]

# %%
#drop all years before 2011
death_index = death_index[death_index['Year'] >= 2011].drop('Other')
death_index.head()
# Out:
#            CaseNumber  Day  Month  Year   Sex   Race   Age ResidenceCity  \
# Date
# 12/29/2012   12-18447   29     12  2012  Male  White  30.0       WOLCOTT
# 10/18/2012   12-14640   18     10  2012  Male  White  19.0       SUDBURY
# 5/30/2012       21885   30      5  2012  Male  White  35.0    BRIDGEPORT
# 6/21/2012       20424   21      6  2012  Male  White  29.0    ROCKY HILL
# 5/24/2012       23346   24      5  2012  Male  Black  53.0    NEW LONDON
#
#            ResidenceCounty   DeathCity    ...     Oxymorphone EtOH  \
# Date                                      ...
# 12/29/2012       NEW HAVEN   WATERBURY    ...             NaN  NaN
# 10/18/2012       MIDDLESEX  BRIDGEPORT    ...             NaN  NaN
# 5/30/2012        FAIRFIELD  BRIDGEPORT    ...             NaN  NaN
# 6/21/2012         HARTFORD    HARTFORD    ...             NaN  NaN
# 5/24/2012       NEW LONDON  NEW LONDON    ...             NaN  NaN
#
#            Hydrocodone Benzodiazepine Methadone Amphet Tramad  \
# Date
# 12/29/2012         NaN            NaN       NaN    NaN    NaN
# 10/18/2012         NaN              Y       NaN    NaN    NaN
# 5/30/2012          NaN            NaN       NaN    NaN    NaN
# 6/21/2012          NaN            NaN       NaN    NaN    NaN
# 5/24/2012          NaN            NaN       NaN    NaN    NaN
#
#            Morphine (not heroin) Other Any Opioid
# Date
# 12/29/2012                   NaN   NaN        NaN
# 10/18/2012                   NaN   NaN        NaN
# 5/30/2012                    NaN   NaN        NaN
# 6/21/2012                    NaN   NaN        NaN
# 5/24/2012                    NaN   NaN        NaN
#
# [5 rows x 27 columns]

# %%
#deterime the number of deaths per year
death_year = death_index.groupby(['Year']).count()

# %%
print(death_year)
# Out:
#       CaseNumber  Day  Month  Sex  Race  Age  ResidenceCity  ResidenceCounty  \
# Year
# 2012         355  355    355  355   355  355            350              334
# 2013         490  490    490  490   490  490            477              460
# 2014         558  558    558  557   555  557            538                0
# 2015         723  723    723  723   722  723            699              686
# 2016         917  917    917  916   913  917            888              883
# 2017         538  538    538  538   537  538            538              522
#
#       DeathCity  DeathCounty     ...      Oxymorphone  EtOH  Hydrocodone  \
# Year                             ...
# 2012        354          352     ...               30    61           15
# 2013        490          488     ...               16    83           19
# 2014        557          408     ...               29   126           15
# 2015        723          717     ...                6   173           20
# 2016        917          440     ...                7   254           20
# 2017        538            0     ...                7    75            9
#
#       Benzodiazepine  Methadone  Amphet  Tramad  Morphine (not heroin)  Other  \
# Year
# 2012              49         33       7       8                      0     39
# 2013              78         47       4       7                      0     48
# 2014             157         51      13      15                      0     60
# 2015             220         71      20      16                     12     75
# 2016             242         84      19      16                     14     77
# 2017             138         50      18      17                     24     21
#
#       Any Opioid
# Year
# 2012           0
# 2013           0
# 2014           0
# 2015         662
# 2016          18
# 2017          30
#
# [6 rows x 26 columns]

# %%
death_year = death_year.drop(['Day','Month','Sex','Race','Age','ResidenceCity', 'ResidenceCounty', 'DeathCity','DeathCounty','Oxymorphone', 'EtOH', 'Hydrocodone','Benzodiazepine','Methadone','Amphet', 'Morphine (not heroin)', 'Tramad','Any Opioid'], axis= 1)
death_year = death_year.drop(['Location','InjuryPlace','Heroin','Cocaine','Fentanyl','Oxycodone', 'Other'], axis=1)
print(death_year)
# Out:
#       CaseNumber
# Year
# 2012         355
# 2013         490
# 2014         558
# 2015         723
# 2016         917
# 2017         538

# %%
death_year.plot(kind='bar',
                   figsize=(8,6),
                   legend=True,
                   color=['navy'],
                   fontsize=14)
pp.show()

# %%
#deterime the monthes with the high deaths
death_month = death_index.groupby(['Month']).count()
print (death_month)
# Out:
#        CaseNumber  Day  Year  Sex  Race  Age  ResidenceCity  ResidenceCounty  \
# Month
# 1             320  320   320  320   319  320            318              263
# 2             326  326   326  326   326  326            323              266
# 3             329  329   329  329   329  329            321              271
# 4             314  314   314  314   311  314            307              260
# 5             326  326   326  326   324  326            318              269
# 6             350  350   350  349   349  349            338              286
# 7             250  250   250  250   250  250            241              207
# 8             237  237   237  237   237  237            229              182
# 9             250  250   250  250   248  250            242              194
# 10            292  292   292  292   292  292            286              228
# 11            307  307   307  307   307  307            295              241
# 12            280  280   280  279   280  280            272              218
#
#        DeathCity  DeathCounty     ...      Oxymorphone  EtOH  Hydrocodone  \
# Month                             ...
# 1            320          185     ...                8    62            9
# 2            326          184     ...                5    64            6
# 3            329          185     ...               10    54           12
# 4            314          233     ...               13    72            6
# 5            325          224     ...                6    63            8
# 6            349          256     ...                4    74            7
# 7            250          174     ...               12    56            5
# 8            237          159     ...                4    63            8
# 9            250          176     ...                5    61           10
# 10           292          223     ...               12    71            7
# 11           307          207     ...                7    74           11
# 12           280          199     ...                9    58            9
#
#        Benzodiazepine  Methadone  Amphet  Tramad  Morphine (not heroin)  \
# Month
# 1                  80         36       9       5                     15
# 2                  76         28       7      12                      5
# 3                  90         33      10       9                      4
# 4                  78         32       8       6                      7
# 5                  78         32       4       7                      7
# 6                  77         29       4       5                      8
# 7                  59         26       4       5                      0
# 8                  51         22      12       4                      2
# 9                  68         23       5       5                      0
# 10                 73         28       7       7                      0
# 11                 82         22       4       6                      1
# 12                 72         25       7       8                      1
#
#        Other  Any Opioid
# Month
# 1         36          57
# 2         30          50
# 3         32          45
# 4         29          56
# 5         27          51
# 6         28          59
# 7         25          75
# 8         29          50
# 9         18          62
# 10        18          88
# 11        30          69
# 12        18          48
#
# [12 rows x 26 columns]

# %%
death_month = death_month.drop(['Day','Year','Sex','Race','Age','ResidenceCity', 'ResidenceCounty', 'DeathCity','DeathCounty','Oxymorphone', 'EtOH', 'Hydrocodone','Benzodiazepine','Methadone','Amphet', 'Morphine (not heroin)', 'Tramad','Any Opioid','Location','InjuryPlace','Heroin','Cocaine','Fentanyl','Oxycodone', 'Other'], axis= 1)
print(death_month)
# Out:
#        CaseNumber
# Month
# 1             320
# 2             326
# 3             329
# 4             314
# 5             326
# 6             350
# 7             250
# 8             237
# 9             250
# 10            292
# 11            307
# 12            280

# %%
death_month.plot(kind='bar',
                   figsize=(12,8),
                   legend=True,
                   color=['navy'],
                   fontsize=14)
pp.show()

# %%
#deterine the day of the month with the highest deaths
death_day = death_index.groupby(['Day']).count()
print (death_day)
# Out:
#      CaseNumber  Month  Year  Sex  Race  Age  ResidenceCity  ResidenceCounty  \
# Day
# 1           117    117   117  117   117  117            113               91
# 2           137    137   137  137   137  137            135              114
# 3           125    125   125  125   124  125            120              103
# 4           135    135   135  135   135  135            131              106
# 5           131    131   131  131   131  131            124              108
# 6           120    120   120  120   120  120            117              100
# 7           111    111   111  111   111  111            109               90
# 8           119    119   119  119   119  119            119               99
# 9           130    130   130  130   130  130            125              103
# 10          107    107   107  107   107  107            106               86
# 11          124    124   124  124   124  124            122               98
# 12          116    116   116  116   116  116            112               87
# 13          119    119   119  119   117  119            116               94
# 14          121    121   121  121   121  121            118               94
# 15           86     86    86   86    86   86             84               72
# 16          112    112   112  112   112  112            110               94
# 17          130    130   130  130   129  130            128              100
# 18          123    123   123  122   123  123            115               98
# 19          108    108   108  108   108  108            104               88
# 20          110    110   110  110   110  110            105               85
# 21          108    108   108  108   108  108            107               87
# 22          110    110   110  110   110  110            108               89
# 23          120    120   120  120   120  120            115               98
# 24          121    121   121  121   120  121            121              103
# 25          114    114   114  114   114  114            113               91
# 26          116    116   116  116   114  116            114               97
# 27          114    114   114  114   113  114            112               89
# 28          101    101   101  100   100  100             98               79
# 29          102    102   102  102   102  102            100               80
# 30          114    114   114  114   114  114            109               98
# 31           80     80    80   80    80   80             80               64
#
#      DeathCity  DeathCounty     ...      Oxymorphone  EtOH  Hydrocodone  \
# Day                             ...
# 1          117           86     ...                5    27            6
# 2          137           80     ...                4    26            3
# 3          125           82     ...                2    31            3
# 4          135           95     ...                0    33            2
# 5          131           82     ...                2    33            3
# 6          120           79     ...                3    24            3
# 7          111           75     ...                2    25            0
# 8          119           77     ...                3    26            4
# 9          130           92     ...                6    24            5
# 10         107           67     ...                1    19            3
# 11         124           75     ...                5    26            3
# 12         116           81     ...                0    21            4
# 13         119           80     ...                3    25            1
# 14         121           88     ...                5    25            3
# 15          86           53     ...                5    22            0
# 16         112           75     ...                5    23            2
# 17         130           96     ...                7    22            7
# 18         123           75     ...                2    32            5
# 19         108           79     ...                4    23            2
# 20         110           69     ...                1    20            3
# 21         108           78     ...                4    21            3
# 22         110           70     ...                1    26            2
# 23         120           81     ...                5    29            2
# 24         121           78     ...                2    19            5
# 25         114           84     ...                3    24            5
# 26         116           79     ...                3    30            3
# 27         114           84     ...                1    29            3
# 28         100           78     ...                3    24            4
# 29         101           57     ...                6    27            3
# 30         114           79     ...                2    22            4
# 31          80           51     ...                0    14            2
#
#      Benzodiazepine  Methadone  Amphet  Tramad  Morphine (not heroin)  Other  \
# Day
# 1                29          9       3       3                      1     12
# 2                38         11       2       5                      0     12
# 3                33         12       6       1                      2     10
# 4                31         12       4       4                      0     11
# 5                32         12       1       4                      4     12
# 6                27         18       3       4                      0      6
# 7                23          7       2       2                      2     10
# 8                33         11       5       4                      2      7
# 9                39         19       3       2                      5      9
# 10               27         17       0       3                      2      7
# 11               33          7       6       5                      1      8
# 12               29          6       2       2                      1     14
# 13               33         15       4       2                      3      9
# 14               29         15       3       2                      1     13
# 15               18          9       0       1                      0      5
# 16               27         14       4       3                      2     13
# 17               30         15       4       2                      0     10
# 18               25         15       2       2                      4     11
# 19               28          6       1       3                      0     11
# 20               25         10       0       2                      2     13
# 21               26          6       4       0                      2     18
# 22               29         11       1       3                      4     11
# 23               23          9       3       2                      1     11
# 24               29          7       5       4                      1     13
# 25               21          7       0       4                      0      7
# 26               34         14       2       1                      2      6
# 27               25         12       3       1                      1     16
# 28               31          9       1       2                      0      9
# 29               20          5       4       2                      4      6
# 30               34          9       1       2                      0     10
# 31               23          7       2       2                      3     10
#
#      Any Opioid
# Day
# 1            26
# 2            23
# 3            24
# 4            33
# 5            29
# 6            22
# 7            17
# 8            19
# 9            29
# 10           18
# 11           16
# 12           30
# 13           20
# 14           28
# 15           18
# 16           15
# 17           26
# 18           27
# 19           27
# 20           22
# 21           25
# 22           18
# 23           20
# 24           25
# 25           24
# 26           26
# 27           27
# 28           23
# 29           12
# 30           23
# 31           18
#
# [31 rows x 26 columns]

# %%
death_day = death_day.drop(['Month','Year','Sex','Race','Age','ResidenceCity', 'ResidenceCounty', 'DeathCity','DeathCounty','Oxymorphone', 'EtOH', 'Hydrocodone','Benzodiazepine','Methadone','Amphet', 'Morphine (not heroin)', 'Tramad','Any Opioid','Location','InjuryPlace','Heroin','Cocaine','Fentanyl','Oxycodone', 'Other'], axis= 1)
print(death_day)
# Out:
#      CaseNumber
# Day
# 1           117
# 2           137
# 3           125
# 4           135
# 5           131
# 6           120
# 7           111
# 8           119
# 9           130
# 10          107
# 11          124
# 12          116
# 13          119
# 14          121
# 15           86
# 16          112
# 17          130
# 18          123
# 19          108
# 20          110
# 21          108
# 22          110
# 23          120
# 24          121
# 25          114
# 26          116
# 27          114
# 28          101
# 29          102
# 30          114
# 31           80

# %%
death_day.plot(kind='bar',
                   figsize=(12,8),
                   legend=True,
                   color=['navy'],
                   fontsize=14)
pp.show()

# %%
#deterine the gender of the deaths
death_sex = death_index.groupby(['Sex']).count()
print (death_sex)
# Out:
#         CaseNumber   Day  Month  Year  Race   Age  ResidenceCity  \
# Sex
# Female         970   970    970   970   966   970            952
# Male          2609  2609   2609  2609  2605  2609           2537
#
#         ResidenceCounty  DeathCity  DeathCounty     ...      Oxymorphone  \
# Sex                                                 ...
# Female              773        970          655     ...               31
# Male               2111       2608         1750     ...               64
#
#         EtOH  Hydrocodone  Benzodiazepine  Methadone  Amphet  Tramad  \
# Sex
# Female   173           45             309        122      30      26
# Male     599           52             574        214      51      53
#
#         Morphine (not heroin)  Other  Any Opioid
# Sex
# Female                     17    121         174
# Male                       33    199         536
#
# [2 rows x 26 columns]

# %%
death_sex = death_sex.drop(['Month','Year','Day','Race','Age','ResidenceCity', 'ResidenceCounty', 'DeathCity','DeathCounty','Oxymorphone', 'EtOH', 'Hydrocodone','Benzodiazepine','Methadone','Amphet', 'Morphine (not heroin)', 'Tramad','Any Opioid','Location','InjuryPlace','Heroin','Cocaine','Fentanyl','Oxycodone', 'Other'], axis= 1)
print(death_sex)
# Out:
#         CaseNumber
# Sex
# Female         970
# Male          2609

# %%
death_sex.plot(kind='bar',
                   figsize=(8,6),
                   legend=True,
                   color=['purple'],
                   fontsize=14)
pp.show()

# %%
#deterime the ethnicity of the deaths
death_race = death_index.groupby(['Race']).count()
print (death_race)
# Out:
#                         CaseNumber   Day  Month  Year   Sex   Age  \
# Race
# Asian Indian                     6     6      6     6     6     6
# Asian, Other                    13    13     13    13    13    13
# Black                          284   284    284   284   284   284
# Chinese                          2     2      2     2     2     2
# Hawaiian                         1     1      1     1     1     1
# Hispanic, Black                 11    11     11    11    11    11
# Hispanic, White                382   382    382   382   381   382
# Native American, Other           1     1      1     1     1     1
# Other                            6     6      6     6     6     6
# Unknown                         14    14     14    14    14    14
# White                         2852  2852   2852  2852  2852  2852
#
#                         ResidenceCity  ResidenceCounty  DeathCity  \
# Race
# Asian Indian                        6                6          6
# Asian, Other                       13               11         13
# Black                             274              241        283
# Chinese                             2                2          2
# Hawaiian                            1                1          1
# Hispanic, Black                    10                7         11
# Hispanic, White                   359              302        382
# Native American, Other              1                1          1
# Other                               5                4          6
# Unknown                            14               13         14
# White                            2798             2292       2852
#
#                         DeathCounty     ...      Oxymorphone  EtOH  \
# Race                                    ...
# Asian Indian                      2     ...                0     1
# Asian, Other                      9     ...                0     1
# Black                           190     ...                0    61
# Chinese                           1     ...                0     0
# Hawaiian                          0     ...                0     0
# Hispanic, Black                   7     ...                0     4
# Hispanic, White                 245     ...                3    75
# Native American, Other            1     ...                0     0
# Other                             5     ...                0     2
# Unknown                          10     ...                2     3
# White                          1931     ...               89   622
#
#                         Hydrocodone  Benzodiazepine  Methadone  Amphet  \
# Race
# Asian Indian                      1               0          0       0
# Asian, Other                      0               3          0       0
# Black                             3              32         15       4
# Chinese                           0               1          0       0
# Hawaiian                          0               1          0       0
# Hispanic, Black                   0               2          0       0
# Hispanic, White                   5              54         36       6
# Native American, Other            1               0          0       0
# Other                             0               2          0       1
# Unknown                           0               2          1       0
# White                            86             784        283      70
#
#                         Tramad  Morphine (not heroin)  Other  Any Opioid
# Race
# Asian Indian                 0                      0      0           0
# Asian, Other                 1                      0      1           1
# Black                        7                      3     34          40
# Chinese                      0                      0      0           1
# Hawaiian                     0                      0      0           1
# Hispanic, Black              2                      0      0           3
# Hispanic, White              8                      2     29          76
# Native American, Other       0                      0      0           0
# Other                        0                      0      0           1
# Unknown                      0                      0      1           2
# White                       61                     45    254         584
#
# [11 rows x 26 columns]

# %%
death_race = death_race.drop(['Month','Year','Day','Sex','Age','ResidenceCity', 'ResidenceCounty', 'DeathCity','DeathCounty','Oxymorphone', 'EtOH', 'Hydrocodone','Benzodiazepine','Methadone','Amphet', 'Morphine (not heroin)', 'Tramad','Any Opioid','Location','InjuryPlace','Heroin','Cocaine','Fentanyl','Oxycodone', 'Other'], axis= 1)
print(death_race)
# Out:
#                         CaseNumber
# Race
# Asian Indian                     6
# Asian, Other                    13
# Black                          284
# Chinese                          2
# Hawaiian                         1
# Hispanic, Black                 11
# Hispanic, White                382
# Native American, Other           1
# Other                            6
# Unknown                         14
# White                         2852

# %%
death_race = death_race.sort_values(by=['CaseNumber'], ascending=False)
print(death_race)
# Out:
#                         CaseNumber
# Race
# White                         2852
# Hispanic, White                382
# Black                          284
# Unknown                         14
# Asian, Other                    13
# Hispanic, Black                 11
# Asian Indian                     6
# Other                            6
# Chinese                          2
# Hawaiian                         1
# Native American, Other           1

# %%
death_race.plot(kind='pie',
                   figsize=(10,10),
                   legend=False,
                   fontsize=14,
                   subplots=True)
pp.show()

# %%
# import 2016 demographic statistics for Conecticut
CTdem = pd.read_csv('/Users/rachela054/Documents/Into to Data Mining/project 2/Datasets/2016_State-level_ASRH.csv')
CTdem.tail()
# Out:
#     Age Group     Mwhite     Fwhite   MBLack   Fblack MAIndian FAIndian  \
# 15  70-74 yrs     53,058     60,939    3,939    5,703      115      129
# 16  75-79 yrs     34,711     43,930    2,615    4,174       89       76
# 17  80-84 yrs     24,851     35,848    1,540    2,868       39       67
# 18    85+ yrs     27,246     54,133    1,275    2,871       50       88
# 19        All  1,194,778  1,256,560  182,771  198,476    4,792    4,811
#
#     Masian  Fasian Non-Hisp\rAll Races   MWhite   FWhite HMBlack HFBlack  \
# 15   1,614   1,872             127,369    3,175    4,161     256     421
# 16   1,291   1,196              88,082    1,942    2,806     181     279
# 17     649     780              66,642    1,178    1,886     117     160
# 18     401     672              86,736    1,057    1,823      83     136
# 19  83,010  88,906           3,014,104  236,383  236,553  32,776  35,592
#
#    HMAIndian HFAindian HMAsian HFAsian Hispanic\rAll Race      Total
# 15        63        91      48      44              8,259    135,628
# 16        41        50      30      32              5,361     93,443
# 17        15        37      11      18              3,422     70,064
# 18        32        33      11      17              3,192     89,928
# 19     6,790     6,270   4,315   3,669            562,348  3,576,452

# %%
CTdem = CTdem.set_index(['Age Group'])

# %%
#use the data from CTdem to create new datafrome to show connecticut's demographics
D_race = {'Race': ['White', 'Hispanic, White', 'Black', 'Asian', 'Hispanic, Black', 'Other'], 'Number': [1194778+1256560, 236383+236553, 182771+198476, 83010+88906, 32776+35592, 3576452 - (1194778+1256560+236383+236553+182771+198476+83010+88906+32776+35592)]}
CTdem_race = pd.DataFrame(data=D_race)
CTdem_race = CTdem_race.set_index(['Race'])
print(CTdem_race)
# Out:
#                   Number
# Race
# White            2451338
# Hispanic, White   472936
# Black             381247
# Asian             171916
# Hispanic, Black    68368
# Other              30647

# %%
CTdem_race.plot(kind='pie',
                   figsize=(10,10),
                   legend=False,
                   fontsize=14,
                   subplots=True)
pp.show()

# %%
#determine the age breakdown of the deaths
death_age = death_index.groupby(['Age']).count()
print (death_age)
# Out:
#       CaseNumber  Day  Month  Year  Sex  Race  ResidenceCity  ResidenceCounty  \
# Age
# 14.0           1    1      1     1    1     1              1                0
# 16.0           1    1      1     1    1     1              1                1
# 17.0           7    7      7     7    7     7              7                6
# 18.0          13   13     13    13   13    13             13               11
# 19.0          20   20     20    20   20    20             20               17
# 20.0          29   29     29    29   29    29             28               24
# 21.0          38   38     38    38   38    38             37               32
# 22.0          51   51     51    51   51    51             49               41
# 23.0          59   59     59    59   59    59             58               48
# 24.0          70   70     70    70   70    70             69               56
# 25.0          71   71     71    71   71    71             71               59
# 26.0          95   95     95    95   95    95             91               76
# 27.0          68   68     68    68   68    67             65               48
# 28.0          92   92     92    92   92    92             87               71
# 29.0         105  105    105   105  105   105            101               83
# 30.0          86   86     86    86   86    86             85               72
# 31.0          81   81     81    81   81    81             79               71
# 32.0          74   74     74    74   74    74             71               61
# 33.0          98   98     98    98   98    98             96               81
# 34.0          87   87     87    87   87    87             85               70
# 35.0          97   97     97    97   97    97             96               71
# 36.0          83   83     83    83   83    83             81               68
# 37.0          81   81     81    81   81    81             80               64
# 38.0          79   79     79    79   79    79             78               68
# 39.0          77   77     77    77   77    77             76               64
# 40.0          80   80     80    80   80    79             79               65
# 41.0          81   81     81    81   81    81             79               61
# 42.0          63   63     63    63   63    63             61               47
# 43.0          83   83     83    83   83    83             79               59
# 44.0         104  104    104   104  104   104            102               77
# ...          ...  ...    ...   ...  ...   ...            ...              ...
# 47.0          93   93     93    93   93    93             89               75
# 48.0          95   95     95    95   95    95             92               74
# 49.0         108  108    108   108  108   107            107               85
# 50.0         104  104    104   104  104   104            101               78
# 51.0         108  108    108   108  108   108            107               92
# 52.0          93   93     93    93   93    91             90               78
# 53.0          83   83     83    83   83    83             81               66
# 54.0         104  104    104   104  103   104            100               80
# 55.0          91   91     91    91   91    91             86               79
# 56.0          79   79     79    79   79    79             76               66
# 57.0          74   74     74    74   74    74             72               66
# 58.0          80   80     80    80   80    80             79               70
# 59.0          61   61     61    61   61    61             59               50
# 60.0          49   49     49    49   49    49             49               45
# 61.0          42   42     42    42   42    42             40               34
# 62.0          35   35     35    35   35    35             35               30
# 63.0          28   28     28    28   28    28             28               25
# 64.0          19   19     19    19   19    19             19               15
# 65.0          14   14     14    14   14    14             14               12
# 66.0          16   16     16    16   16    16             16               14
# 67.0           9    9      9     9    9     9              9                7
# 68.0           7    7      7     7    7     6              7                5
# 69.0           4    4      4     4    4     4              3                3
# 70.0           7    7      7     7    7     7              7                4
# 71.0           8    8      8     8    8     8              8                6
# 72.0           8    8      8     8    8     8              8                7
# 73.0           4    4      4     4    4     3              4                4
# 75.0           2    2      2     2    2     2              2                1
# 81.0           1    1      1     1    1     1              1                0
# 87.0           1    1      1     1    1     1              1                1
#
#       DeathCity  DeathCounty     ...      Oxymorphone  EtOH  Hydrocodone  \
# Age                              ...
# 14.0          1            0     ...                0     0            0
# 16.0          1            1     ...                1     0            0
# 17.0          7            5     ...                1     0            0
# 18.0         13           10     ...                2     0            0
# 19.0         20           14     ...                0     3            0
# 20.0         29           25     ...                0     3            0
# 21.0         38           32     ...                1     5            0
# 22.0         51           38     ...                0     6            0
# 23.0         59           36     ...                3    11            0
# 24.0         70           52     ...                0     9            0
# 25.0         71           43     ...                0    17            0
# 26.0         95           70     ...                1     9            1
# 27.0         68           46     ...                3    12            1
# 28.0         92           68     ...                2    15            3
# 29.0        105           74     ...                2    20            1
# 30.0         86           61     ...                0    17            3
# 31.0         81           55     ...                2    20            1
# 32.0         74           53     ...                2     9            0
# 33.0         98           58     ...                1    22            0
# 34.0         87           51     ...                2    17            4
# 35.0         97           63     ...                0    20            2
# 36.0         83           49     ...                1    18            1
# 37.0         80           46     ...                1    12            1
# 38.0         79           50     ...                3    17            1
# 39.0         77           53     ...                2    12            3
# 40.0         80           46     ...                2    12            0
# 41.0         81           52     ...                2    17            2
# 42.0         63           45     ...                2    19            1
# 43.0         83           56     ...                1    24            2
# 44.0        104           75     ...                4    20            3
# ...         ...          ...     ...              ...   ...          ...
# 47.0         93           70     ...                4    21            4
# 48.0         95           65     ...                1    21            4
# 49.0        108           74     ...                3    31            2
# 50.0        104           69     ...                7    27            7
# 51.0        108           72     ...                3    35            7
# 52.0         93           62     ...                3    20            5
# 53.0         83           59     ...                3    27            2
# 54.0        104           63     ...                4    34            1
# 55.0         91           64     ...                5    25            2
# 56.0         79           48     ...                2    17            4
# 57.0         74           46     ...                2    19            4
# 58.0         80           54     ...                2    21            2
# 59.0         61           37     ...                4    13            1
# 60.0         49           26     ...                3    10            0
# 61.0         42           24     ...                1     9            1
# 62.0         35           18     ...                0     9            3
# 63.0         28           21     ...                0     9            0
# 64.0         19           11     ...                0     4            0
# 65.0         14            9     ...                1     3            3
# 66.0         16            9     ...                0     2            0
# 67.0          9            6     ...                0     1            0
# 68.0          7            6     ...                0     1            0
# 69.0          4            3     ...                0     0            2
# 70.0          7            6     ...                0     1            2
# 71.0          8            5     ...                0     0            0
# 72.0          8            6     ...                0     1            3
# 73.0          4            3     ...                0     2            0
# 75.0          2            2     ...                1     0            0
# 81.0          1            1     ...                0     0            0
# 87.0          1            1     ...                0     0            0
#
#       Benzodiazepine  Methadone  Amphet  Tramad  Morphine (not heroin)  Other  \
# Age
# 14.0               0          0       0       0                      0      0
# 16.0               0          0       0       0                      0      0
# 17.0               2          0       1       0                      0      1
# 18.0               4          0       1       0                      0      2
# 19.0               4          0       0       0                      0      0
# 20.0               9          2       0       0                      0      2
# 21.0               7          1       2       2                      0      3
# 22.0               7          4       2       0                      0      4
# 23.0              15          3       3       0                      0      4
# 24.0              13          1       1       0                      0      7
# 25.0              17          2       3       1                      1      2
# 26.0              11          5       1       2                      0      7
# 27.0              18          9       0       1                      1     11
# 28.0              19          5       4       1                      1      7
# 29.0              21          5       3       2                      0      6
# 30.0              18          6       1       0                      0      4
# 31.0              19          4       3       0                      0      6
# 32.0              21         14       0       0                      0      8
# 33.0              26          8       3       1                      3      9
# 34.0              15         14       6       0                      0     10
# 35.0              27          8       2       1                      2      9
# 36.0              27          7       3       1                      0     11
# 37.0              26         10       1       2                      1      9
# 38.0              23          5       6       2                      1     12
# 39.0              20          5       0       0                      0      9
# 40.0              16          7       2       2                      1      8
# 41.0              18          9       3       0                      1      7
# 42.0              13          9       2       3                      0      4
# 43.0              23          7       0       2                      0      7
# 44.0              23          8       2       4                      3      7
# ...              ...        ...     ...     ...                    ...    ...
# 47.0              13         12       0       1                      0      6
# 48.0              29         14       2       3                      1      9
# 49.0              28         13       1       3                      1      7
# 50.0              22          6       1       1                      1      2
# 51.0              27          9       5       4                      1     11
# 52.0              24          8       0       2                      2      7
# 53.0              25         12       2       3                      2      8
# 54.0              26         11       0       3                      4     11
# 55.0              30          8       1       2                      1      7
# 56.0              20         10       3       2                      3     11
# 57.0              25          8       3       3                      3      7
# 58.0              22         14       2       2                      0      4
# 59.0              19          6       0       3                      3      4
# 60.0              13          7       1       3                      2      3
# 61.0               9          2       0       4                      2      7
# 62.0              12          6       1       2                      1      2
# 63.0               6          4       0       2                      1      6
# 64.0               3          3       0       0                      0      1
# 65.0               2          0       1       1                      0      0
# 66.0               6          0       0       1                      1      4
# 67.0               4          0       0       1                      0      1
# 68.0               3          1       0       0                      0      2
# 69.0               2          0       0       1                      0      0
# 70.0               2          2       0       1                      0      0
# 71.0               1          0       0       1                      0      2
# 72.0               4          0       0       0                      1      1
# 73.0               1          0       0       0                      0      0
# 75.0               1          0       0       0                      0      1
# 81.0               0          0       0       0                      0      1
# 87.0               0          0       0       0                      0      0
#
#       Any Opioid
# Age
# 14.0           0
# 16.0           0
# 17.0           2
# 18.0           2
# 19.0           5
# 20.0           6
# 21.0          12
# 22.0           6
# 23.0          12
# 24.0          17
# 25.0          16
# 26.0          18
# 27.0          14
# 28.0          24
# 29.0          19
# 30.0          15
# 31.0          15
# 32.0          15
# 33.0          24
# 34.0          15
# 35.0          21
# 36.0          15
# 37.0          15
# 38.0          21
# 39.0          20
# 40.0          10
# 41.0           9
# 42.0          12
# 43.0          15
# 44.0          12
# ...          ...
# 47.0          14
# 48.0          14
# 49.0          24
# 50.0          19
# 51.0          20
# 52.0          17
# 53.0          16
# 54.0          17
# 55.0          28
# 56.0          15
# 57.0          11
# 58.0          14
# 59.0          18
# 60.0          12
# 61.0           5
# 62.0          12
# 63.0           8
# 64.0           3
# 65.0           5
# 66.0           1
# 67.0           1
# 68.0           2
# 69.0           2
# 70.0           2
# 71.0           3
# 72.0           5
# 73.0           1
# 75.0           0
# 81.0           0
# 87.0           0
#
# [62 rows x 26 columns]

# %%
death_age = death_age.drop(['Month','Year','Day','Sex','Race','ResidenceCity', 'ResidenceCounty', 'DeathCity','DeathCounty','Oxymorphone', 'EtOH', 'Hydrocodone','Benzodiazepine','Methadone','Amphet', 'Morphine (not heroin)', 'Tramad','Any Opioid','Location','InjuryPlace','Heroin','Cocaine','Fentanyl','Oxycodone', 'Other'], axis= 1)
print(death_age)
# Out:
#       CaseNumber
# Age
# 14.0           1
# 16.0           1
# 17.0           7
# 18.0          13
# 19.0          20
# 20.0          29
# 21.0          38
# 22.0          51
# 23.0          59
# 24.0          70
# 25.0          71
# 26.0          95
# 27.0          68
# 28.0          92
# 29.0         105
# 30.0          86
# 31.0          81
# 32.0          74
# 33.0          98
# 34.0          87
# 35.0          97
# 36.0          83
# 37.0          81
# 38.0          79
# 39.0          77
# 40.0          80
# 41.0          81
# 42.0          63
# 43.0          83
# 44.0         104
# ...          ...
# 47.0          93
# 48.0          95
# 49.0         108
# 50.0         104
# 51.0         108
# 52.0          93
# 53.0          83
# 54.0         104
# 55.0          91
# 56.0          79
# 57.0          74
# 58.0          80
# 59.0          61
# 60.0          49
# 61.0          42
# 62.0          35
# 63.0          28
# 64.0          19
# 65.0          14
# 66.0          16
# 67.0           9
# 68.0           7
# 69.0           4
# 70.0           7
# 71.0           8
# 72.0           8
# 73.0           4
# 75.0           2
# 81.0           1
# 87.0           1
#
# [62 rows x 1 columns]

# %%
death_age.plot(kind='line',
                   figsize=(14,8),
                   legend=False,
                   fontsize=14,
                   subplots=True)
pp.show()

# %%
#where do the the people who overdose live
death_county = death_index.groupby(['ResidenceCounty']).count()
print (death_county)
# Out:
#                      CaseNumber  Day  Month  Year  Sex  Race  Age  \
# ResidenceCounty
# AROOSTOOK                     1    1      1     1    1     1    1
# BERKSHIRE                     1    1      1     1    1     1    1
# CHESAPEAKE CITY               1    1      1     1    1     1    1
# COLLIER                       1    1      1     1    1     1    1
# COOK                          1    1      1     1    1     1    1
# CUMBERLAND                    1    1      1     1    1     1    1
# CUYAHOGA                      1    1      1     1    1     1    1
# DAKOTA                        1    1      1     1    1     1    1
# DUTCHESS                      8    8      8     8    8     8    8
# ESSEX                         5    5      5     5    5     5    5
# FAIRFIELD                   454  454    454   454  454   454  454
# FRANKLIN                      1    1      1     1    1     1    1
# GLOUCESTER                    1    1      1     1    1     1    1
# HAMPDEN                       3    3      3     3    3     3    3
# HAMPSHIRE                     1    1      1     1    1     1    1
# HARRIS                        2    2      2     2    2     2    2
# HARTFORD                    784  784    784   784  783   782  784
# HIGHLANDS                     1    1      1     1    1     1    1
# HILLSBOROUGH                  1    1      1     1    1     1    1
# HORRY                         1    1      1     1    1     1    1
# JEFFERSON                     1    1      1     1    1     1    1
# KINGS                         1    1      1     1    1     1    1
# KNOX                          1    1      1     1    1     1    1
# LAKE                          1    1      1     1    1     1    1
# LITCHFIELD                  175  175    175   175  175   174  175
# LOS ANGELES                   1    1      1     1    1     1    1
# MADISON                       1    1      1     1    1     1    1
# MIAMI-DADE                    1    1      1     1    1     1    1
# MIDDLESEX                   134  134    134   134  134   134  134
# MUSCOGEE                      1    1      1     1    1     1    1
# ...                         ...  ...    ...   ...  ...   ...  ...
# NEW CASTLE                    1    1      1     1    1     1    1
# NEW HAVEN                   757  757    757   757  757   756  757
# NEW LONDON                  284  284    284   284  284   284  284
# NEW YORK                      3    3      3     3    3     3    3
# NEWPORT                       1    1      1     1    1     1    1
# NORFOLK                       1    1      1     1    1     1    1
# OCEAN                         1    1      1     1    1     1    1
# ORANGE                        3    3      3     3    3     3    3
# PASSAIC                       1    1      1     1    1     1    1
# PROVIDENCE                    1    1      1     1    1     1    1
# PUTNAM                        2    2      2     2    2     2    2
# QUEENS                        1    1      1     1    1     1    1
# ROGERS                        1    1      1     1    1     1    1
# SANTA CRUZ                    1    1      1     1    1     1    1
# SARATOGA                      1    1      1     1    1     1    1
# SCHENECTADY                   1    1      1     1    1     1    1
# ST JOHN THE BAPTIST           1    1      1     1    1     1    1
# SUFFOLK                       2    2      2     2    2     2    2
# TOLLAND                      89   89     89    89   89    89   89
# ULSTER                        1    1      1     1    1     1    1
# UNKNOWN                      28   28     28    28   28    28   28
# USA                           1    1      1     1    1     1    1
# WASHINGTON                    1    1      1     1    1     1    1
# WELD                          1    1      1     1    1     1    1
# WESTCHESTER                  11   11     11    11   11    11   11
# WESTMORELAND                  1    1      1     1    1     1    1
# WINDHAM                      97   97     97    97   97    96   97
# WINNEBAGO                     1    1      1     1    1     1    1
# WORCESTER                     2    2      2     2    2     2    2
# YANKTON                       1    1      1     1    1     1    1
#
#                      ResidenceCity  DeathCity  DeathCounty     ...      \
# ResidenceCounty                                                ...
# AROOSTOOK                        1          1            0     ...
# BERKSHIRE                        1          1            1     ...
# CHESAPEAKE CITY                  1          1            1     ...
# COLLIER                          1          1            1     ...
# COOK                             1          1            1     ...
# CUMBERLAND                       1          1            1     ...
# CUYAHOGA                         1          1            1     ...
# DAKOTA                           1          1            1     ...
# DUTCHESS                         8          8            6     ...
# ESSEX                            5          5            4     ...
# FAIRFIELD                      454        453          311     ...
# FRANKLIN                         1          1            0     ...
# GLOUCESTER                       1          1            0     ...
# HAMPDEN                          3          3            2     ...
# HAMPSHIRE                        1          1            0     ...
# HARRIS                           2          2            1     ...
# HARTFORD                       784        784          498     ...
# HIGHLANDS                        1          1            0     ...
# HILLSBOROUGH                     1          1            1     ...
# HORRY                            1          1            0     ...
# JEFFERSON                        1          1            0     ...
# KINGS                            1          1            0     ...
# KNOX                             1          1            0     ...
# LAKE                             1          1            1     ...
# LITCHFIELD                     175        175          124     ...
# LOS ANGELES                      1          1            1     ...
# MADISON                          1          1            1     ...
# MIAMI-DADE                       1          1            1     ...
# MIDDLESEX                      134        134           94     ...
# MUSCOGEE                         1          1            1     ...
# ...                            ...        ...          ...     ...
# NEW CASTLE                       1          1            1     ...
# NEW HAVEN                      757        757          512     ...
# NEW LONDON                     284        284          190     ...
# NEW YORK                         3          3            3     ...
# NEWPORT                          1          1            0     ...
# NORFOLK                          1          1            1     ...
# OCEAN                            1          1            0     ...
# ORANGE                           3          3            2     ...
# PASSAIC                          1          1            0     ...
# PROVIDENCE                       1          1            0     ...
# PUTNAM                           2          2            2     ...
# QUEENS                           1          1            1     ...
# ROGERS                           1          1            0     ...
# SANTA CRUZ                       1          1            1     ...
# SARATOGA                         1          1            1     ...
# SCHENECTADY                      1          1            0     ...
# ST JOHN THE BAPTIST              1          1            1     ...
# SUFFOLK                          2          2            1     ...
# TOLLAND                         89         89           61     ...
# ULSTER                           1          1            0     ...
# UNKNOWN                         28         28            0     ...
# USA                              1          1            1     ...
# WASHINGTON                       1          1            0     ...
# WELD                             1          1            0     ...
# WESTCHESTER                     11         11            7     ...
# WESTMORELAND                     1          1            0     ...
# WINDHAM                         97         97           57     ...
# WINNEBAGO                        1          1            1     ...
# WORCESTER                        2          2            2     ...
# YANKTON                          1          1            0     ...
#
#                      Oxymorphone  EtOH  Hydrocodone  Benzodiazepine  \
# ResidenceCounty
# AROOSTOOK                      0     0            0               0
# BERKSHIRE                      0     0            0               1
# CHESAPEAKE CITY                0     1            0               0
# COLLIER                        0     0            0               0
# COOK                           0     0            1               1
# CUMBERLAND                     0     0            0               1
# CUYAHOGA                       0     0            0               1
# DAKOTA                         0     1            0               0
# DUTCHESS                       0     0            0               0
# ESSEX                          0     0            0               2
# FAIRFIELD                     12   119           14             132
# FRANKLIN                       0     1            0               1
# GLOUCESTER                     0     0            0               0
# HAMPDEN                        0     1            0               0
# HAMPSHIRE                      0     0            0               0
# HARRIS                         0     0            0               0
# HARTFORD                      15   166           22             162
# HIGHLANDS                      0     0            0               1
# HILLSBOROUGH                   0     1            0               1
# HORRY                          0     0            0               1
# JEFFERSON                      0     0            0               1
# KINGS                          0     0            0               0
# KNOX                           0     0            0               0
# LAKE                           0     0            0               0
# LITCHFIELD                     5    35            5              36
# LOS ANGELES                    0     1            0               0
# MADISON                        0     0            0               0
# MIAMI-DADE                     0     1            0               0
# MIDDLESEX                      5    25            3              33
# MUSCOGEE                       0     0            0               1
# ...                          ...   ...          ...             ...
# NEW CASTLE                     0     0            0               1
# NEW HAVEN                     16   147           16             210
# NEW LONDON                     7    51           14              58
# NEW YORK                       0     1            0               2
# NEWPORT                        0     1            0               0
# NORFOLK                        0     0            0               0
# OCEAN                          0     1            0               1
# ORANGE                         1     2            0               0
# PASSAIC                        0     0            0               0
# PROVIDENCE                     0     0            0               1
# PUTNAM                         0     1            0               1
# QUEENS                         0     0            0               0
# ROGERS                         0     1            0               0
# SANTA CRUZ                     0     0            0               0
# SARATOGA                       0     0            0               0
# SCHENECTADY                    0     0            0               0
# ST JOHN THE BAPTIST            0     0            0               1
# SUFFOLK                        0     1            0               0
# TOLLAND                        0    19            5              20
# ULSTER                         0     0            0               0
# UNKNOWN                        1     6            0               5
# USA                            0     0            0               0
# WASHINGTON                     0     0            0               0
# WELD                           0     0            0               0
# WESTCHESTER                    1     3            1               2
# WESTMORELAND                   0     1            0               0
# WINDHAM                        1    22            1              20
# WINNEBAGO                      0     0            0               0
# WORCESTER                      0     1            0               1
# YANKTON                        0     0            0               0
#
#                      Methadone  Amphet  Tramad  Morphine (not heroin)  Other  \
# ResidenceCounty
# AROOSTOOK                    0       0       0                      0      0
# BERKSHIRE                    0       0       0                      0      0
# CHESAPEAKE CITY              0       0       0                      0      0
# COLLIER                      0       0       0                      1      1
# COOK                         0       0       0                      0      0
# CUMBERLAND                   0       0       0                      1      1
# CUYAHOGA                     0       0       0                      1      0
# DAKOTA                       0       0       0                      0      0
# DUTCHESS                     1       0       1                      0      0
# ESSEX                        0       1       0                      0      1
# FAIRFIELD                   53      16       6                      4     36
# FRANKLIN                     0       0       0                      0      0
# GLOUCESTER                   0       0       0                      0      0
# HAMPDEN                      0       0       0                      0      1
# HAMPSHIRE                    0       0       0                      0      0
# HARRIS                       0       0       0                      0      0
# HARTFORD                    50      11      16                     11     62
# HIGHLANDS                    0       1       0                      0      0
# HILLSBOROUGH                 0       0       0                      0      0
# HORRY                        0       0       0                      0      0
# JEFFERSON                    0       0       0                      0      0
# KINGS                        0       0       0                      0      0
# KNOX                         1       0       0                      0      0
# LAKE                         0       0       0                      0      0
# LITCHFIELD                  13       4       5                      5     17
# LOS ANGELES                  0       0       0                      0      0
# MADISON                      0       0       0                      0      1
# MIAMI-DADE                   0       0       0                      0      1
# MIDDLESEX                   10       1       3                      2     10
# MUSCOGEE                     0       0       0                      0      0
# ...                        ...     ...     ...                    ...    ...
# NEW CASTLE                   0       0       0                      0      0
# NEW HAVEN                  106      19      16                     16     67
# NEW LONDON                  16       3       6                      3     30
# NEW YORK                     0       0       0                      0      1
# NEWPORT                      0       0       0                      0      0
# NORFOLK                      0       0       0                      0      0
# OCEAN                        0       0       0                      0      0
# ORANGE                       0       0       0                      0      1
# PASSAIC                      0       0       0                      0      0
# PROVIDENCE                   0       0       0                      0      0
# PUTNAM                       0       0       0                      0      1
# QUEENS                       0       0       0                      0      0
# ROGERS                       0       0       0                      0      0
# SANTA CRUZ                   0       0       0                      0      0
# SARATOGA                     0       0       0                      0      0
# SCHENECTADY                  0       0       0                      0      0
# ST JOHN THE BAPTIST          0       0       0                      0      1
# SUFFOLK                      0       1       0                      0      0
# TOLLAND                      4       2       4                      2      6
# ULSTER                       0       0       0                      0      0
# UNKNOWN                      2       1       0                      0      0
# USA                          1       0       0                      0      0
# WASHINGTON                   0       1       0                      0      0
# WELD                         0       0       0                      0      0
# WESTCHESTER                  0       0       0                      1      3
# WESTMORELAND                 0       0       0                      0      0
# WINDHAM                      7       2       4                      2      8
# WINNEBAGO                    0       0       0                      0      0
# WORCESTER                    0       1       0                      0      0
# YANKTON                      0       1       0                      0      0
#
#                      Any Opioid
# ResidenceCounty
# AROOSTOOK                     0
# BERKSHIRE                     0
# CHESAPEAKE CITY               0
# COLLIER                       1
# COOK                          1
# CUMBERLAND                    0
# CUYAHOGA                      0
# DAKOTA                        0
# DUTCHESS                      1
# ESSEX                         3
# FAIRFIELD                    99
# FRANKLIN                      0
# GLOUCESTER                    0
# HAMPDEN                       1
# HAMPSHIRE                     0
# HARRIS                        0
# HARTFORD                    187
# HIGHLANDS                     0
# HILLSBOROUGH                  0
# HORRY                         0
# JEFFERSON                     0
# KINGS                         0
# KNOX                          0
# LAKE                          0
# LITCHFIELD                   49
# LOS ANGELES                   1
# MADISON                       0
# MIAMI-DADE                    0
# MIDDLESEX                    35
# MUSCOGEE                      1
# ...                         ...
# NEW CASTLE                    0
# NEW HAVEN                   181
# NEW LONDON                   57
# NEW YORK                      1
# NEWPORT                       0
# NORFOLK                       0
# OCEAN                         0
# ORANGE                        1
# PASSAIC                       0
# PROVIDENCE                    0
# PUTNAM                        1
# QUEENS                        0
# ROGERS                        0
# SANTA CRUZ                    0
# SARATOGA                      0
# SCHENECTADY                   0
# ST JOHN THE BAPTIST           1
# SUFFOLK                       0
# TOLLAND                      24
# ULSTER                        0
# UNKNOWN                       0
# USA                           0
# WASHINGTON                    0
# WELD                          0
# WESTCHESTER                   3
# WESTMORELAND                  0
# WINDHAM                      24
# WINNEBAGO                     0
# WORCESTER                     1
# YANKTON                       0
#
# [61 rows x 26 columns]

# %%
death_county = death_county.sort_values(by=['CaseNumber'], ascending=False)

# %%
death_county = death_county.head(6)
death_county.head(6)
# Out:
#                  CaseNumber  Day  Month  Year  Sex  Race  Age  ResidenceCity  \
# ResidenceCounty
# HARTFORD                784  784    784   784  783   782  784            784
# NEW HAVEN               757  757    757   757  757   756  757            757
# FAIRFIELD               454  454    454   454  454   454  454            454
# NEW LONDON              284  284    284   284  284   284  284            284
# LITCHFIELD              175  175    175   175  175   174  175            175
# MIDDLESEX               134  134    134   134  134   134  134            134
#
#                  DeathCity  DeathCounty     ...      Oxymorphone  EtOH  \
# ResidenceCounty                             ...
# HARTFORD               784          498     ...               15   166
# NEW HAVEN              757          512     ...               16   147
# FAIRFIELD              453          311     ...               12   119
# NEW LONDON             284          190     ...                7    51
# LITCHFIELD             175          124     ...                5    35
# MIDDLESEX              134           94     ...                5    25
#
#                  Hydrocodone  Benzodiazepine  Methadone  Amphet  Tramad  \
# ResidenceCounty
# HARTFORD                  22             162         50      11      16
# NEW HAVEN                 16             210        106      19      16
# FAIRFIELD                 14             132         53      16       6
# NEW LONDON                14              58         16       3       6
# LITCHFIELD                 5              36         13       4       5
# MIDDLESEX                  3              33         10       1       3
#
#                  Morphine (not heroin)  Other  Any Opioid
# ResidenceCounty
# HARTFORD                            11     62         187
# NEW HAVEN                           16     67         181
# FAIRFIELD                            4     36          99
# NEW LONDON                           3     30          57
# LITCHFIELD                           5     17          49
# MIDDLESEX                            2     10          35
#
# [6 rows x 26 columns]

# %%
death_county = death_county.drop(['Day','Month','Year','Day','Sex','Race','ResidenceCity', 'DeathCity','DeathCounty','Oxymorphone', 'EtOH', 'Hydrocodone','Benzodiazepine','Methadone','Amphet', 'Morphine (not heroin)', 'Tramad','Any Opioid','Location','InjuryPlace','Heroin','Cocaine','Fentanyl','Oxycodone', 'Other'], axis= 1)
print(death_county)
# Out:
#                  CaseNumber  Age
# ResidenceCounty
# HARTFORD                784  784
# NEW HAVEN               757  757
# FAIRFIELD               454  454
# NEW LONDON              284  284
# LITCHFIELD              175  175
# MIDDLESEX               134  134

# %%
death_county = death_county.drop(['Age'], axis=1)

# %%
death_county.head(6)
# Out:
#                  CaseNumber
# ResidenceCounty
# HARTFORD                784
# NEW HAVEN               757
# FAIRFIELD               454
# NEW LONDON              284
# LITCHFIELD              175
# MIDDLESEX               134

# %%
death_county.plot(kind='bar',
                   figsize=(10,6),
                   legend=False,
                   fontsize=14,
                   subplots=True)
pp.show()

# %%
#determine the thw most frequent opioid in overdoes victims
death_type = death_index

# %%
death_type['Cocaine'].replace('Y', 1 ,inplace=True)
death_type['Heroin'].replace('Y', 1 ,inplace=True)
death_type['Fentanyl'].replace('Y', 1 ,inplace=True)
death_type['Oxycodone'].replace('Y', 1 ,inplace=True)
death_type['EtOH'].replace('Y', 1 ,inplace=True)
death_type['Hydrocodone'].replace('Y', 1 ,inplace=True)
death_type['Benzodiazepine'].replace('Y', 1 ,inplace=True)
death_type['Methadone'].replace('Y', 1 ,inplace=True)
death_type['Amphet'].replace('Y', 1 ,inplace=True)
death_type['Tramad'].replace('Y', 1 ,inplace=True)
death_type['Morphine (not heroin)'].replace('Y', 1 ,inplace=True)

death_type = death_type.drop(['Month','Year','Day','Sex','Race','ResidenceCity', 'ResidenceCounty', 'DeathCity','DeathCounty','Oxymorphone','Location','InjuryPlace', 'Any Opioid', 'Other', 'Age'], axis= 1)
death_type = death_type.fillna(0)

death_type.head(30)
# Out:
#            CaseNumber Heroin Cocaine Fentanyl Oxycodone EtOH Hydrocodone  \
# Date
# 12/29/2012   12-18447      0       1        0         1    0           0
# 10/18/2012   12-14640      1       0        0         0    0           0
# 5/30/2012       21885      1       0        0         0    0           0
# 6/21/2012       20424      1       0        0         0    0           0
# 5/24/2012       23346      1       0        0         0    0           0
# 8/27/2012    12-12055      0       1        0         0    0           0
# 8/15/2012    12-11530      1       0        0         0    0           0
# 9/30/2012    12-13673      1       1        0         0    0           0
# 8/18/2012    12-11672      1       0        0         0    0           0
# 10/4/2012    12-13932      0       0        0         1    0           0
# 4/3/2012        28460      0       1        0         0    0           0
# 3/23/2012       19694      1       0        0         0    0           0
# 7/15/2012    12-10000      1       0        0         1    1           0
# 11/11/2012   12-15843      0       0        0         0    1           0
# 3/12/2012       24442      1       0        0         0    0           1
# 1/5/2012       12-252      0       0        0         0    0           0
# 4/1/2012        20059      1       1        0         0    1           0
# 11/9/2012    12-15786      0       0        0         1    0           0
# 8/29/2012    12-12217      0       0        0         1    0           1
# 8/9/2012     12-11203      1       0        0         0    1           0
# 2/21/2012       30651      0       0        0         0    0           0
# 1/15/2012      12-803      1       0        0         0    0           0
# 8/22/2012    12-11895      1       0        0         1    0           0
# 4/22/2012       33573      1       1        0         0    1           0
# 7/1/2012        43088      0       0        0         0    0           0
# 1/14/2012      12-746      1       1        0         0    0           0
# 10/23/2012   12-14886      1       0        0         1    0           0
# 6/10/2012       21520      1       0        0         0    0           0
# 9/9/2012     12-12714      1       1        0         0    0           0
# 3/3/2012        27729      0       1        0         0    0           0
#
#            Benzodiazepine Methadone  Amphet  Tramad Morphine (not heroin)
# Date
# 12/29/2012              0         0     0.0     0.0                     0
# 10/18/2012              1         0     0.0     0.0                     0
# 5/30/2012               0         0     0.0     0.0                     0
# 6/21/2012               0         0     0.0     0.0                     0
# 5/24/2012               0         0     0.0     0.0                     0
# 8/27/2012               0         0     0.0     0.0                     0
# 8/15/2012               0         0     0.0     0.0                     0
# 9/30/2012               0         0     0.0     0.0                     0
# 8/18/2012               0         0     0.0     0.0                     0
# 10/4/2012               0         0     0.0     0.0                     0
# 4/3/2012                0         0     0.0     0.0                     0
# 3/23/2012               0         0     0.0     0.0                     0
# 7/15/2012               0         0     0.0     0.0                     0
# 11/11/2012              0         0     0.0     0.0                     0
# 3/12/2012               1         0     0.0     0.0                     0
# 1/5/2012                0         1     0.0     0.0                     0
# 4/1/2012                0         0     0.0     0.0                     0
# 11/9/2012               1         0     0.0     0.0                     0
# 8/29/2012               0         0     0.0     0.0                     0
# 8/9/2012                0         0     0.0     0.0                     0
# 2/21/2012               0         1     0.0     0.0                     0
# 1/15/2012               0         1     0.0     0.0                     0
# 8/22/2012               1         0     0.0     0.0                     0
# 4/22/2012               0         0     0.0     0.0                     0
# 7/1/2012                0         1     0.0     1.0                     0
# 1/14/2012               0         0     0.0     0.0                     0
# 10/23/2012              0         0     0.0     0.0                     0
# 6/10/2012               0         0     0.0     0.0                     0
# 9/9/2012                0         1     0.0     0.0                     0
# 3/3/2012                0         0     0.0     0.0                     0

# %%
death_type.Heroin.unique()
# Out:
# array([0, 1, 'y', ' '], dtype=object)

# %%
death_type['Cocaine'].replace('y', 1 ,inplace=True)
death_type['Heroin'].replace('y', 1 ,inplace=True)
death_type['Fentanyl'].replace('y', 1 ,inplace=True)
death_type['Oxycodone'].replace('y', 1 ,inplace=True)
death_type['EtOH'].replace('y', 1 ,inplace=True)
death_type['Hydrocodone'].replace('y', 1 ,inplace=True)
death_type['Benzodiazepine'].replace('y', 1 ,inplace=True)
death_type['Methadone'].replace('y', 1 ,inplace=True)
death_type['Amphet'].replace('y', 1 ,inplace=True)
death_type['Tramad'].replace('y', 1 ,inplace=True)
death_type['Morphine (not heroin)'].replace('y', 1 ,inplace=True)

death_type['Cocaine'].replace(' ', 0 ,inplace=True)
death_type['Heroin'].replace(' ', 0 ,inplace=True)
death_type['Fentanyl'].replace(' ', 0 ,inplace=True)
death_type['Oxycodone'].replace(' ', 0 ,inplace=True)
death_type['EtOH'].replace(' ', 0 ,inplace=True)
death_type['Hydrocodone'].replace(' ', 0 ,inplace=True)
death_type['Benzodiazepine'].replace(' ', 0 ,inplace=True)
death_type['Methadone'].replace(' ', 0 ,inplace=True)
death_type['Amphet'].replace(' ', 0 ,inplace=True)
death_type['Tramad'].replace(' ', 0 ,inplace=True)
death_type['Morphine (not heroin)'].replace(' ', 0 ,inplace=True)

death_type.head()
# Out:
#            CaseNumber  Heroin  Cocaine Fentanyl  Oxycodone  EtOH  Hydrocodone  \
# Date
# 12/29/2012   12-18447       0        1        0          1     0            0
# 10/18/2012   12-14640       1        0        0          0     0            0
# 5/30/2012       21885       1        0        0          0     0            0
# 6/21/2012       20424       1        0        0          0     0            0
# 5/24/2012       23346       1        0        0          0     0            0
#
#             Benzodiazepine  Methadone  Amphet  Tramad Morphine (not heroin)
# Date
# 12/29/2012               0          0     0.0     0.0                     0
# 10/18/2012               1          0     0.0     0.0                     0
# 5/30/2012                0          0     0.0     0.0                     0
# 6/21/2012                0          0     0.0     0.0                     0
# 5/24/2012                0          0     0.0     0.0                     0

# %%
Heroin = death_type['Heroin'].sum()
print(Heroin)
Cocaine = death_type['Cocaine'].sum()
print(Cocaine)
# Out:
# 1933
# 997

# %%
death_type.Fentanyl.unique()
# Out:
# array([0, 1, 'Y POPS', 'Y (PTCH)', 'Y-A'], dtype=object)

# %%
death_type['Fentanyl'].replace('Y POPS', 1 ,inplace=True)
death_type['Fentanyl'].replace('Y (PTCH)', 1 ,inplace=True)
death_type['Fentanyl'].replace('Y-A', 1 ,inplace=True)

# %%
Fentanyl = death_type['Fentanyl'].sum()
print(Fentanyl)
Oxycodone = death_type['Oxycodone'].sum()
print(Oxycodone)
EtOH = death_type['EtOH'].sum()
print(EtOH)
Hydrocodone = death_type['Hydrocodone'].sum()
print(Hydrocodone)
Benzodiazepine = death_type['Benzodiazepine'].sum()
print(Benzodiazepine)
Methadone = death_type['Methadone'].sum()
print(Methadone)
Amphet = death_type['Amphet'].sum()
print(Amphet)
Tramad = death_type['Tramad'].sum()
print(Tramad)
# Out:
# 1114
# 491
# 772
# 98
# 884
# 336
# 81.0
# 79.0

# %%
death_type['Morphine (not heroin)'].unique()
# Out:
# array([0, 1, 'NO RX BUT STRAWS', 'STOLE MEDS', 'PCP neg', ' Y'], dtype=object)

# %%
death_type['Morphine (not heroin)'].replace('NO RX BUT STRAWS', 1 ,inplace=True)
death_type['Morphine (not heroin)'].replace('STOLE MEDS', 1 ,inplace=True)
death_type['Morphine (not heroin)'].replace('PCP neg', 1 ,inplace=True)
death_type['Morphine (not heroin)'].replace(' Y', 1 ,inplace=True)

# %%
Morphine = death_type['Morphine (not heroin)'].sum()
print(Morphine)
# Out:
# 32

# %%
death_typetotal = pd.DataFrame({'Opioid': ['Heroin', 'Cocaine', 'Fentanyl', 'Oxycodone', 'EtOH', 'Hydrocodone', 'Benzodiazepine', 'Methadone', 'Amphet', 'Tramad', 'Morphine (not heroin)'],
                   'Number of Deaths': [1933, 997, 1114, 491, 772, 98, 884, 336, 81, 79, 32],
                   })
print(death_typetotal)
# Out:
#     Number of Deaths                 Opioid
# 0               1933                 Heroin
# 1                997                Cocaine
# 2               1114               Fentanyl
# 3                491              Oxycodone
# 4                772                   EtOH
# 5                 98            Hydrocodone
# 6                884         Benzodiazepine
# 7                336              Methadone
# 8                 81                 Amphet
# 9                 79                 Tramad
# 10                32  Morphine (not heroin)

# %%
death_typetotal = death_typetotal.set_index(['Opioid'])

# %%
death_typetotal.plot(kind='bar',
                   figsize=(12,6),
                   legend=False,
                   fontsize=14,
                   subplots=True)
pp.show()

# %%
#are heroin overdoses increacing or decreasing? 
death_heroin = death_index.drop(['Day','Month','Sex','Race','Age','ResidenceCity','ResidenceCounty','DeathCity', 'DeathCounty','Location','InjuryPlace','Cocaine','Fentanyl',
 'Oxycodone','Oxymorphone','EtOH','Hydrocodone','Benzodiazepine','Methadone','Amphet','Tramad','Morphine (not heroin)','Other',
 'Any Opioid'], axis= 1)
death_heroin.head()
# Out:
#            CaseNumber  Year Heroin
# Date
# 12/29/2012   12-18447  2012    NaN
# 10/18/2012   12-14640  2012      1
# 5/30/2012       21885  2012      1
# 6/21/2012       20424  2012      1
# 5/24/2012       23346  2012      1

# %%
death_heroin['Heroin'].replace('Y', 1 ,inplace=True)
death_heroin['Heroin'].replace('y', 1 ,inplace=True)
death_heroin['Heroin'].replace(' ', 0 ,inplace=True)
death_heroin['Heroin'].replace(' nan', 0 ,inplace=True)
death_heroin['Heroin'].unique()
# Out:
# array([ nan,   1.,   0.])

# %%
death_heroin = death_heroin[death_heroin.Heroin == 1]
death_heroin.head(10)
# Out:
#            CaseNumber  Year  Heroin
# Date
# 10/18/2012   12-14640  2012     1.0
# 5/30/2012       21885  2012     1.0
# 6/21/2012       20424  2012     1.0
# 5/24/2012       23346  2012     1.0
# 8/15/2012    12-11530  2012     1.0
# 9/30/2012    12-13673  2012     1.0
# 8/18/2012    12-11672  2012     1.0
# 3/23/2012       19694  2012     1.0
# 7/15/2012    12-10000  2012     1.0
# 3/12/2012       24442  2012     1.0

# %%
death_heroin = death_heroin.groupby(['Year']).count()
print (death_heroin)
# Out:
#       CaseNumber  Heroin
# Year
# 2012         174     174
# 2013         257     257
# 2014         325     325
# 2015         415     415
# 2016         504     504
# 2017         258     258

# %%
death_heroin = death_heroin.drop(['CaseNumber'], axis=1)

# %%
death_heroin.plot(kind='bar',
                   figsize=(12,6),
                   legend=False,
                   fontsize=14,
                   subplots=True)
pp.show()

# %%
#find trenads in Fentanyl usage
death_Fentanyl = death_index.drop(['Day','Month','Sex','Race','Age','ResidenceCity','ResidenceCounty','DeathCity', 'DeathCounty','Location','InjuryPlace','Cocaine','Heroin',
 'Oxycodone','Oxymorphone','EtOH','Hydrocodone','Benzodiazepine','Methadone','Amphet','Tramad','Morphine (not heroin)','Other',
 'Any Opioid'], axis= 1)
death_Fentanyl.head()
# Out:
#            CaseNumber  Year Fentanyl
# Date
# 12/29/2012   12-18447  2012      NaN
# 10/18/2012   12-14640  2012      NaN
# 5/30/2012       21885  2012      NaN
# 6/21/2012       20424  2012      NaN
# 5/24/2012       23346  2012      NaN

# %%
death_Fentanyl['Fentanyl'].unique()
# Out:
# array([nan, 1, 'Y POPS', 'Y (PTCH)', 'Y-A', 'y'], dtype=object)

# %%
death_Fentanyl['Fentanyl'].replace('Y', 1 ,inplace=True)
death_Fentanyl['Fentanyl'].replace('y', 1 ,inplace=True)
death_Fentanyl['Fentanyl'].replace('Y POPS', 1 ,inplace=True)
death_Fentanyl['Fentanyl'].replace('Y (PTCH)', 1 ,inplace=True)
death_Fentanyl['Fentanyl'].replace('Y-A', 0 ,inplace=True)

death_Fentanyl.head()
# Out:
#            CaseNumber  Year  Fentanyl
# Date
# 12/29/2012   12-18447  2012       NaN
# 10/18/2012   12-14640  2012       NaN
# 5/30/2012       21885  2012       NaN
# 6/21/2012       20424  2012       NaN
# 5/24/2012       23346  2012       NaN

# %%
death_Fentanyl = death_Fentanyl.dropna(subset=['Fentanyl'])
death_Fentanyl.head()
# Out:
#            CaseNumber  Year  Fentanyl
# Date
# 6/20/2012       43085  2012       1.0
# 11/25/2012   12-16579  2012       1.0
# 11/30/2012   12-16897  2012       1.0
# 7/3/2012        17137  2012       1.0
# 10/9/2012    12-14100  2012       1.0

# %%
death_Fentanyl = death_Fentanyl.groupby(['Year']).count()
print (death_Fentanyl)
# Out:
#       CaseNumber  Fentanyl
# Year
# 2012          14        14
# 2013          37        37
# 2014          75        75
# 2015         186       186
# 2016         479       479
# 2017         323       323

# %%
death_Fentanyl = death_Fentanyl.drop(['CaseNumber'], axis=1)

# %%
death_Fentanyl.plot(kind='bar',
                   figsize=(12,6),
                   legend=False,
                   fontsize=14,
                   subplots=True)
pp.show()
